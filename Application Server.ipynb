# %%
#pip install Flask requests

# %%
# System Call Log Creation:

# %%
import csv
# Write header
#writer.writerow(["Itr_Num", "Layer_Name", "Process_Name", "Log_Prompt"])

def Call_log( Layer_Name, Process_Name, Log_Prompt):
    # Define the CSV file name
    csv_filename = "System_Call_Log.csv"
    # Write data to CSV file
    with open(csv_filename, mode="a+", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["ITr Num", Layer_Name, Process_Name, Log_Prompt])

# %% [markdown]
# #  Application Server
# Application server receives the response from the cloud server. It displays the current condition of soil cover field. **receive_trigger_result** receives the trigger response at backend.**ShowAnalysisResult** is the html frontpage which shows the result to user.
# Running on http://localhost:5000/results

# %%
from flask import Flask, request, jsonify, render_template_string

app = Flask(__name__)

# In-memory storage for results
results = []

@app.route('/result', methods=['POST'])
def receive_trigger_result():
    data = request.json
    results.clear()  # Clear previous result
    results.append(data)  # Add the new resul
    return jsonify({"status": "Received", "data": data})

@app.route('/results')
def ShowAnalysisResult():
    html = """
    <!DOCTYPE html>
    <html lang="en">
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title> Dashboard</title>
        <style>
            body {
                font-family: Arial, sans-serif;
                background-color: #f4f4f4;
                margin: 0;
                padding: 0;
            }
            .container {
                width: 80%;
                margin: auto;
                overflow: hidden;
            }
            header {
                background: #333;
                color: #fff;
                padding-top: 30px;
                min-height: 70px;
                border-bottom: #77c3dd 3px solid;
            }
            header a {
                color: #fff;
                text-decoration: none;
                text-transform: uppercase;
                font-size: 16px;
            }
            .content {
                padding: 20px;
                background: #fff;
                margin-top: 20px;
                box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
            }
            h1 {
                text-align: center;
                margin-bottom: 20px;
            }
            ul {
                list-style: none;
                padding: 0;
            }
            li {
                background: #e4e4e4;
                margin: 10px 0;
                padding: 10px;
                border-left: 5px solid #333;
            }
            li:nth-child(even) {
                background: #ccc;
            }
            .timestamp {
                font-size: 12px;
                color: #555;
                float: right;
            }
        </style>
    </head>
    <body>
        <header>
            <div class="container">
                <h1> Dashboard</h1>
            </div>
        </header>
        <div class="container content">
            <h2>Results from Soil Cover Model</h2>
            <ul>
                {% for result in results %}
                <li>
                    <strong>{{ result.task }} - {{ result.status }}</strong>: {{ result.output }}
                    <span class="timestamp">{{ result.timestamp }}</span>
                </li>
                {% endfor %}
            </ul>
        </div>
    </body>
    </html>
    """
    return render_template_string(html, results=results)

# %%
#Running on http://localhost:5000/results
# Uncomment the following lines to run the server directly in the Jupyter Notebook
from werkzeug.serving import run_simple
run_simple('localhost', 5000, app)
# Out:
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [14/Feb/2025 21:27:40] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2025 21:27:55] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2025 21:29:41] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2025 21:29:56] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2025 21:33:12] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2025 21:33:27] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2025 21:33:42] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2025 21:33:57] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2025 21:34:42] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2025 21:35:43] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2025 21:39:44] "POST /result HTTP/1.1" 200 -
# ...
